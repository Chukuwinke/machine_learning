# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Preprocessing

# %% [markdown]
#    ### Data extraction:

# %%
#reading file from csv
auto_data = pd.read_csv('./Resources/adverts.csv')

# %%
# making a copy of the data and using only a sample of the data
a_data_copy = auto_data.copy().sample(n=5000, ignore_index=True)

# visualy inspecting data
print(a_data_copy.shape)
a_data_copy.head(15)
# Out:
# (5000, 12)
#     public_reference   mileage reg_code standard_colour standard_make  \
# 0    202009073406619   66900.0       66            Grey          Audi
# 1    202008303098379   27444.0       66           White       Citroen
# 2    202009103542521   13226.0       69          Silver         SKODA
# 3    202005039159319    5998.0       69     Multicolour          Audi
# 4    202009193943005   71000.0       63            Blue       Hyundai
# 5    202008052129622  103000.0       09            Blue         Honda
# 6    202009013181166   92689.0       10           White          Fiat
# 7    202010134938778   37697.0       18            Blue         Volvo
# 8    202008192693636   34000.0       16            Grey       Peugeot
# 9    202010165059424   43347.0       63           Black      Vauxhall
# 10   202010285539426      50.0       70            Grey       Citroen
# 11   202010014431330   38246.0       16             Red        Toyota
# 12   202008252903861       0.0      NaN            Blue        Suzuki
# 13   202007201453440  125000.0       60           Black           BMW
# 14   202010024516047   32990.0       66            Blue          Fiat
#
#    standard_model vehicle_condition  year_of_registration  price    body_type  \
# 0              A3              USED                2016.0  13490    Hatchback
# 1              C1              USED                2016.0   4875    Hatchback
# 2         Octavia              USED                2019.0  14500    Hatchback
# 3    A5 Cabriolet              USED                2020.0  28851  Convertible
# 4            ix35              USED                2013.0   7000          SUV
# 5            Jazz              USED                2009.0   2395    Hatchback
# 6             500              USED                2010.0   2490    Hatchback
# 7             V40              USED                2018.0  13700    Hatchback
# 8            3008              USED                2016.0   9200          SUV
# 9        Insignia              USED                2013.0   8990    Hatchback
# 10             C1              USED                2020.0  14295    Hatchback
# 11          Yaris              USED                2016.0  11440    Hatchback
# 12    SX4 S-Cross               NEW                   NaN  28299          SUV
# 13       1 Series              USED                2010.0   3488  Convertible
# 14            500              USED                2017.0   6700    Hatchback
#
#     crossover_car_and_van      fuel_type
# 0                   False         Petrol
# 1                   False         Petrol
# 2                   False         Diesel
# 3                   False         Diesel
# 4                   False         Diesel
# 5                   False         Petrol
# 6                   False         Diesel
# 7                   False         Petrol
# 8                   False         Diesel
# 9                   False         Diesel
# 10                  False         Petrol
# 11                  False  Petrol Hybrid
# 12                  False  Petrol Hybrid
# 13                  False         Diesel
# 14                  False         Petrol

# %% [markdown]
# ### Data exploration:

# %%
# Data Types of the columns
a_data_copy.dtypes
# Out:
# public_reference           int64
# mileage                  float64
# reg_code                  object
# standard_colour           object
# standard_make             object
# standard_model            object
# vehicle_condition         object
# year_of_registration     float64
# price                      int64
# body_type                 object
# crossover_car_and_van       bool
# fuel_type                 object
# dtype: object

# %%
#finding all null or nan values in data
a_data_copy.isnull().sum()
# Out:
# public_reference           0
# mileage                    0
# reg_code                 399
# standard_colour           63
# standard_make              0
# standard_model             0
# vehicle_condition          0
# year_of_registration     423
# price                      0
# body_type                  7
# crossover_car_and_van      0
# fuel_type                  4
# dtype: int64

# %%
#checking to see if there are any duplicate rows
a_data_copy.public_reference.duplicated().sum()
# Out:
# 0

# %%
#checking the values in each column
for column in a_data_copy.columns:
    print(a_data_copy[column].value_counts())
# Out:
# 202009073406619    1
# 202010175110871    1
# 202009123632678    1
# 202010175103064    1
# 202010134967932    1
#                   ..
# 202009093500431    1
# 202003208639333    1
# 202007241633607    1
# 202009173855428    1
# 202010305596173    1
# Name: public_reference, Length: 5000, dtype: int64
# 0.0         212
# 10.0        164
# 60000.0      25
# 5.0          25
# 40000.0      20
#            ...
# 131143.0      1
# 11295.0       1
# 14103.0       1
# 44792.0       1
# 17850.0       1
# Name: mileage, Length: 3253, dtype: int64
# 17    475
# 67    417
# 69    326
# 66    307
# 18    275
# 16    242
# 68    204
# 19    200
# 65    185
# 20    169
# 15    161
# 64    155
# 14    149
# 70    137
# 63    122
# 13    119
# 61     96
# 62     90
# 12     87
# 10     75
# 59     71
# 11     67
# 60     62
# 09     55
# 08     53
# 07     39
# 57     37
# 56     30
# 58     28
# 05     25
# 06     21
# 54     19
# 04     19
# 55     15
# 03     11
# 52      9
# 02      7
# Y       7
# W       7
# 53      5
# X       5
# 51      4
# P       3
# F       2
# R       2
# E       1
# S       1
# N       1
# G       1
# M       1
# T       1
# K       1
# Name: reg_code, dtype: int64
# Black          1102
# White           906
# Grey            820
# Blue            734
# Silver          613
# Red             503
# Green            57
# Orange           53
# Yellow           34
# Bronze           25
# Brown            23
# Multicolour      23
# Beige            12
# Pink              9
# Purple            8
# Gold              8
# Maroon            2
# Burgundy          2
# Turquoise         1
# Magenta           1
# Navy              1
# Name: standard_colour, dtype: int64
# BMW               466
# Audi              436
# Volkswagen        435
# Vauxhall          396
# Mercedes-Benz     383
# Nissan            253
# Toyota            229
# Peugeot           195
# Land Rover        195
# Kia               157
# SKODA             156
# MINI              155
# Hyundai           152
# Renault           145
# Volvo             143
# Fiat              130
# SEAT              126
# Honda             119
# Citroen           107
# Mazda              80
# Jaguar             80
# Suzuki             61
# Porsche            51
# Dacia              41
# Mitsubishi         36
# Jeep               32
# Lexus              31
# Alfa Romeo         23
# Smart              22
# MG                 18
# Subaru             17
# Abarth             16
# DS AUTOMOBILES     16
# Ferrari            15
# SsangYong          13
# Lamborghini        11
# Bentley            10
# Maserati            6
# Rolls-Royce         6
# Aston Martin        6
# Chevrolet           5
# Saab                4
# Tesla               4
# Isuzu               3
# Dodge               3
# Chrysler            3
# Infiniti            2
# Lotus               2
# Daewoo              1
# Cadillac            1
# TVR                 1
# McLaren             1
# Holden              1
# Name: standard_make, dtype: int64
# Golf        161
# Corsa        99
# C Class      98
# 1 Series     98
# Qashqai      94
#            ...
# Bentayga      1
# Viper         1
# 355 F1        1
# Allroad       1
# V70           1
# Name: standard_model, Length: 468, dtype: int64
# USED    4609
# NEW      391
# Name: vehicle_condition, dtype: int64
# 2017.0    889
# 2016.0    536
# 2018.0    486
# 2019.0    477
# 2020.0    377
# 2015.0    336
# 2014.0    298
# 2013.0    230
# 2012.0    183
# 2011.0    156
# 2010.0    138
# 2009.0    118
# 2008.0     86
# 2007.0     75
# 2006.0     48
# 2005.0     39
# 2004.0     36
# 2002.0     18
# 2003.0     16
# 2000.0     10
# 2001.0     10
# 1997.0      4
# 1989.0      3
# 1998.0      2
# 1961.0      1
# 1995.0      1
# 1994.0      1
# 1999.0      1
# 1972.0      1
# 1981.0      1
# Name: year_of_registration, dtype: int64
# 7995     36
# 10995    32
# 8995     32
# 11995    31
# 12000    28
#          ..
# 17588     1
# 56995     1
# 15808     1
# 18215     1
# 6360      1
# Name: price, Length: 2189, dtype: int64
# Hatchback      2116
# SUV            1474
# Saloon          454
# Estate          287
# Coupe           264
# Convertible     203
# MPV             174
# Pickup           12
# Combi Van         3
# Limousine         3
# Panel Van         2
# Camper            1
# Name: body_type, dtype: int64
# False    4980
# True       20
# Name: crossover_car_and_van, dtype: int64
# Petrol                   2751
# Diesel                   1885
# Petrol Hybrid             174
# Electric                   79
# Petrol Plug-in Hybrid      78
# Diesel Hybrid              21
# Diesel Plug-in Hybrid       6
# Bi Fuel                     2
# Name: fuel_type, dtype: int64

# %% [markdown]
# #### Based on initial visual analysis the next step is to select a subset of features of intrest and perform further analsis

# %%
data_subset = a_data_copy[['mileage', 'reg_code', 'standard_colour',
       'standard_make', 'standard_model', 'vehicle_condition',
       'year_of_registration', 'body_type', 'crossover_car_and_van',
       'fuel_type','price']]

data_subset.head(10)
# Out:
#     mileage reg_code standard_colour standard_make standard_model  \
# 0   66900.0       66            Grey          Audi             A3
# 1   27444.0       66           White       Citroen             C1
# 2   13226.0       69          Silver         SKODA        Octavia
# 3    5998.0       69     Multicolour          Audi   A5 Cabriolet
# 4   71000.0       63            Blue       Hyundai           ix35
# 5  103000.0       09            Blue         Honda           Jazz
# 6   92689.0       10           White          Fiat            500
# 7   37697.0       18            Blue         Volvo            V40
# 8   34000.0       16            Grey       Peugeot           3008
# 9   43347.0       63           Black      Vauxhall       Insignia
#
#   vehicle_condition  year_of_registration    body_type  crossover_car_and_van  \
# 0              USED                2016.0    Hatchback                  False
# 1              USED                2016.0    Hatchback                  False
# 2              USED                2019.0    Hatchback                  False
# 3              USED                2020.0  Convertible                  False
# 4              USED                2013.0          SUV                  False
# 5              USED                2009.0    Hatchback                  False
# 6              USED                2010.0    Hatchback                  False
# 7              USED                2018.0    Hatchback                  False
# 8              USED                2016.0          SUV                  False
# 9              USED                2013.0    Hatchback                  False
#
#   fuel_type  price
# 0    Petrol  13490
# 1    Petrol   4875
# 2    Diesel  14500
# 3    Diesel  28851
# 4    Diesel   7000
# 5    Petrol   2395
# 6    Diesel   2490
# 7    Petrol  13700
# 8    Diesel   9200
# 9    Diesel   8990

# %%
# get quantitative features
quant_features = data_subset.select_dtypes(include=['int64', 'float64'])

# get qualitative features
qual_features = data_subset.select_dtypes(exclude=['int64', 'float64'])
#quant_features["price"] = np.log(quant_features["price"])
#quant_features["price"] = quant_features["price"].astype(float)
#quant_features["price"].describe()

# %% [markdown]
# ### Quantitative data subset analysis for exploration

# %%
# Pre Quantitative data outlier handling
for col in quant_features:
    fig, ax =plt.subplots(1, constrained_layout=True)
    fig.set_size_inches(20, 3)
    sns.boxplot(data =quant_features[col], x=quant_features[col],  color='red')
    #plt.suptitle(f'{col.title()} (before handling outliers)',weight='bold')

# %%
quant_features.hist(bins=60, figsize=(20,10))
# Out:
# array([[<AxesSubplot:title={'center':'mileage'}>,
#         <AxesSubplot:title={'center':'year_of_registration'}>],
#        [<AxesSubplot:title={'center':'price'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
# Checking percentage of outliers in quantitative subset
def outlier_prcnt(data):
    for col_name in data.columns:
        q1 = data[col_name].quantile(0.25)
        q3 = data[col_name].quantile(0.75)
        iqr = q3-q1  #IQR
        fence_low  = q1-1.5*iqr
        fence_high = q3+1.5*iqr

        
        outliers = ((data[col_name] > fence_high) | (data[col_name] < fence_low)).sum()
        total = data[col_name].shape[0]
        print(f"Total outliers in {col_name} are: {outliers} - {round(100*(outliers)/total,2)}%.")

outlier_prcnt(quant_features)
# Out:
# Total outliers in mileage are: 117 - 2.34%.
# Total outliers in year_of_registration are: 144 - 2.88%.
# Total outliers in price are: 308 - 6.16%.

# %%
# Checking cleaning outliers in quantitative subset
def outlier_handle(data):
    df_new = data.copy()
    for col_name in data.columns:
        if col_name == "mileage" or col_name == "price":
            q1 = data[col_name].quantile(0.25)
            q3 = data[col_name].quantile(0.75)
            iqr = q3-q1  #IQR
            fence_low  = q1-1.5*iqr
            fence_high = q3+1.5*iqr
            df_new.loc[:,  col_name] = np.where(data[col_name]> fence_high, fence_high,
                                             np.where(data[col_name]< fence_low, fence_low,
                                                      data[col_name]))
    return df_new
quant_features = outlier_handle(quant_features)

# %%
#  Post Quantitative data outlier handling
for col in quant_features:
    fig, ax =plt.subplots(1, constrained_layout=True)
    fig.set_size_inches(20, 3)
    sns.boxplot(data =quant_features[col], x=quant_features[col],  color='green')
    #plt.suptitle(f'{col.title()} (before handling outliers)',weight='bold')

# %%
# checking outliers in quantitative features
quant_features.hist(bins=60, figsize=(20,10))
# Out:
# array([[<AxesSubplot:title={'center':'mileage'}>,
#         <AxesSubplot:title={'center':'year_of_registration'}>],
#        [<AxesSubplot:title={'center':'price'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
quant_features.describe()
# Out:
#              mileage  year_of_registration         price
# count    5000.000000           4577.000000   5000.000000
# mean    36434.368625           2015.159056  15284.120900
# std     32637.263157              4.183828  10310.032954
# min         0.000000           1961.000000    300.000000
# 25%     10076.250000           2013.000000   7600.000000
# 50%     27973.500000           2016.000000  12628.000000
# 75%     55000.000000           2018.000000  20467.750000
# max    122385.625000           2020.000000  39769.375000

# %% [markdown]
# ### Qualitative data subset analysis for exploration

# %%
qual_features.columns
# Out:
# Index(['reg_code', 'standard_colour', 'standard_make', 'standard_model',
#        'vehicle_condition', 'body_type', 'crossover_car_and_van', 'fuel_type'],
#       dtype='object')

# %%
price = quant_features["price"]
qual_features_subset = qual_features.drop(columns='reg_code')
qual_features_subset.head(15)
# Out:
#    standard_colour standard_make standard_model vehicle_condition  \
# 0             Grey          Audi             A3              USED
# 1            White       Citroen             C1              USED
# 2           Silver         SKODA        Octavia              USED
# 3      Multicolour          Audi   A5 Cabriolet              USED
# 4             Blue       Hyundai           ix35              USED
# 5             Blue         Honda           Jazz              USED
# 6            White          Fiat            500              USED
# 7             Blue         Volvo            V40              USED
# 8             Grey       Peugeot           3008              USED
# 9            Black      Vauxhall       Insignia              USED
# 10            Grey       Citroen             C1              USED
# 11             Red        Toyota          Yaris              USED
# 12            Blue        Suzuki    SX4 S-Cross               NEW
# 13           Black           BMW       1 Series              USED
# 14            Blue          Fiat            500              USED
#
#       body_type  crossover_car_and_van      fuel_type
# 0     Hatchback                  False         Petrol
# 1     Hatchback                  False         Petrol
# 2     Hatchback                  False         Diesel
# 3   Convertible                  False         Diesel
# 4           SUV                  False         Diesel
# 5     Hatchback                  False         Petrol
# 6     Hatchback                  False         Diesel
# 7     Hatchback                  False         Petrol
# 8           SUV                  False         Diesel
# 9     Hatchback                  False         Diesel
# 10    Hatchback                  False         Petrol
# 11    Hatchback                  False  Petrol Hybrid
# 12          SUV                  False  Petrol Hybrid
# 13  Convertible                  False         Diesel
# 14    Hatchback                  False         Petrol

# %%
# converting categorical values to type string to improve visualisation of data
for col in qual_features_subset.columns:
     qual_features_subset[col] = qual_features_subset[col].astype(str)
qual_features_subset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   standard_colour        5000 non-null   object
#  1   standard_make          5000 non-null   object
#  2   standard_model         5000 non-null   object
#  3   vehicle_condition      5000 non-null   object
#  4   body_type              5000 non-null   object
#  5   crossover_car_and_van  5000 non-null   object
#  6   fuel_type              5000 non-null   object
# dtypes: object(7)
# memory usage: 273.6+ KB

# %%
# finding the total amount of unique categorical values
for col in qual_features_subset:
    amount_unique = len(qual_features_subset[col].unique())
    print(f"feature:{col} total:{amount_unique} \n" )
# Out:
# feature:standard_colour total:22
#
# feature:standard_make total:53
#
# feature:standard_model total:468
#
# feature:vehicle_condition total:2
#
# feature:body_type total:13
#
# feature:crossover_car_and_van total:2
#
# feature:fuel_type total:9

# %%
# visualizing categorical data in comparison to price
for col in qual_features_subset:
    amount_unique = len(qual_features_subset[col].unique())
    fig, ax =plt.subplots(1, constrained_layout=True)
    if not col == "price":
        if amount_unique <= 13:
            fig.set_size_inches(13, 3)
            sns.barplot(data=qual_features_subset, y=price, x=col)
        else:
            fig.set_size_inches(20, 10)
            sns.scatterplot(data=qual_features_subset, y=price, x=col)

# %%
#data_subset[data_subset["year_of_registration"]<= 2000]
#a_data_copy[a_data_copy["price"]<= 17316]
#a_data_copy[a_data_copy["mileage"]>= 200000]
#quant_features["mileage"].describe()

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt 
# plt.figure(figsize=(10, 10))
# sns.set(font_scale=.9)
# sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, cmap='RdBu')
# plt.show()

# %%
#np.log10(quant_features["price"]).hist(bins=60, figsize=(20,10))

# %% [markdown]
# > During the initial observation of the data, multiple inconsistency such as ** NAN ** values were discovered
# >
# > as well as colums with mixed types. Valuable insights into the data was gained.

# %%
# converting NAN values in each column into mean or mode of the column
# data_col = a_data_copy.columns
# for header in data_col:
#     dc = a_data_copy[header]
#     if a_data_copy[header].dtypes =='O':
#         dc_m = dc.fillna(a_data_copy[header].mode().iloc[0])
#     else:
#         dc_m = dc.fillna(value = a_data_copy[header].mean())
#     a_data_copy.update({header: dc_m})
    
# a_data_copy.isnull().sum()
